# %%
print("Hello world")
# Out:
# Hello world

# %%
well_data = {
    "hello" : "world",
    "salman" : "saeed"
}
print(well_data)
# Out:
# {'hello': 'world', 'salman': 'saeed'}

# %%
student_name = "salman saeed"
student_age = 19
student_studyhours = 7
exam_score = 3.33
passed_exam = True

# %%
def calculate_error(actual , predicted):
    error = abs(actual - predicted)
    return error

calculate_error(5000 , 6000)
# Out:
# 1000

# %%
daily_production = [4200, 4300, 4150, 4400, 4500]

for i  in daily_production:
    print(i)
# Out:
# 4200
# 4300
# 4150
# 4400
# 4500

# %%
for i in daily_production:
    if i > 4000:
        print("good production : " , i)
    else:
        print("Not good production : " , i)
# Out:
# good production :  4200
# good production :  4300
# good production :  4150
# good production :  4400
# good production :  4500

# %%
import numpy as np
production = np.array([1 , 2 , 3, 4 , 5])

# %%
print(production)
# Out:
# [1 2 3 4 5]
