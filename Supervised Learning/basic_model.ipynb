# %%
import numpy as np

X_train = np.array([
    [2104, 5, 1, 45],
    [1416, 3, 2, 40],
    [1534, 3, 2, 30],
    [852, 2, 1, 36],
    [1940, 4, 2, 20],
    [2000, 3, 2, 25],
    [1890, 3, 1, 18],
    [4478, 5, 3, 12],
    [1268, 3, 1, 50],
    [2300, 4, 2, 15],
    [1320, 2, 1, 35],
    [2800, 4, 2, 10],
    [3100, 5, 2, 8],
    [1750, 3, 2, 22],
    [2200, 4, 2, 16],
    [1450, 3, 1, 28],
    [1650, 3, 2, 24],
    [2500, 4, 2, 11],
    [3500, 5, 3, 6],
    [4100, 5, 3, 4]
])

y_train = np.array([
    460,
    232,
    315,
    178,
    420,
    450,
    390,
    880,
    220,
    520,
    250,
    610,
    690,
    360,
    500,
    300,
    345,
    560,
    760,
    900
])
