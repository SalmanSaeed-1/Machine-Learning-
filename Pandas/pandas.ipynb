# %%
import pandas as pd

# %%
ages = pd.Series([22, 25, 30, 28])

print(ages)
# Out:
# 0    22
# 1    25
# 2    30
# 3    28
# dtype: int64

# %%
Data = {
    "Name" : ["Salman" , "Zeeshan" , "Mahnoor" , "Zainab"],
    "Age" : [20 , 23 , 21, 20],
    "gender" : ["Male" , "Male" , "Female" , "Female"],
    "Salary" : [50000000 , 3000000 , 4000000 , 200000] 
}

df = pd.DataFrame(Data)
print(df)
# Out:
#       Name  Age  gender    Salary
# 0   Salman   20    Male  50000000
# 1  Zeeshan   23    Male   3000000
# 2  Mahnoor   21  Female   4000000
# 3   Zainab   20  Female    200000

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'gender', 'Salary'], dtype='str')

# %%
print(df.head(2))
# Out:
#       Name  Age gender    Salary
# 0   Salman   20   Male  50000000
# 1  Zeeshan   23   Male   3000000

# %%
print(df.tail(2))
# Out:
#       Name  Age  gender   Salary
# 2  Mahnoor   21  Female  4000000
# 3   Zainab   20  Female   200000

# %%
print(df.shape)
# Out:
# (4, 4)

# %%
print(df.dtypes)
# Out:
# Name        str
# Age       int64
# gender      str
# Salary    int64
# dtype: object

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of       Name  Age  gender    Salary
# 0   Salman   20    Male  50000000
# 1  Zeeshan   23    Male   3000000
# 2  Mahnoor   21  Female   4000000
# 3   Zainab   20  Female    200000>

# %%
print(df[["Name" , "Age"]])
# Out:
#       Name  Age
# 0   Salman   20
# 1  Zeeshan   23
# 2  Mahnoor   21
# 3   Zainab   20

# %%
print(df.loc[0])   #loc function
# Out:
# Name        Salman
# Age             20
# gender        Male
# Salary    50000000
# Name: 0, dtype: object

# %%
print(df.loc[1])
# Out:
# Name      Zeeshan
# Age            23
# gender       Male
# Salary    3000000
# Name: 1, dtype: object

# %%
print(df.iloc[0])
# Out:
# Name        Salman
# Age             20
# gender        Male
# Salary    50000000
# Name: 0, dtype: object

# %%
print(df[df["Salary"] > 30000000])
# Out:
#      Name  Age gender    Salary
# 0  Salman   20   Male  50000000

# %%
print(df[(df["Age"] > 25) & (df["Salary"] > 600)])
# Out:
# Empty DataFrame
# Columns: [Name, Age, gender, Salary]
# Index: []

# %%
df["Salary after bonus"] = df["Salary"] * 34

# %%
print(df)
# Out:
#       Name  Age  gender    Salary  Salary after bonus
# 0   Salman   20    Male  50000000          1700000000
# 1  Zeeshan   23    Male   3000000           102000000
# 2  Mahnoor   21  Female   4000000           136000000
# 3   Zainab   20  Female    200000             6800000

# %%
df["Age group"] = df["Age"].apply(lambda x : "Adult" if x > 20 else "Young")
print(df)
# Out:
#       Name  Age  gender    Salary  Salary after bonus Age group
# 0   Salman   20    Male  50000000          1700000000     Young
# 1  Zeeshan   23    Male   3000000           102000000     Adult
# 2  Mahnoor   21  Female   4000000           136000000     Adult
# 3   Zainab   20  Female    200000             6800000     Young

# %%
X = df[["Age" , "Name"]]
Y = df["Salary"]
print(X)
# Out:
#    Age     Name
# 0   20   Salman
# 1   23  Zeeshan
# 2   21  Mahnoor
# 3   20   Zainab

# %%
print(Y)
# Out:
# 0    50000000
# 1     3000000
# 2     4000000
# 3      200000
# Name: Salary, dtype: int64

# %%
df = pd.read_csv("industry.csv")

# %%
df.head()
# Out:
#                         Industry
# 0             Accounting/Finance
# 1   Advertising/Public Relations
# 2             Aerospace/Aviation
# 3  Arts/Entertainment/Publishing
# 4                     Automotive

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Industry  43 non-null     str
# dtypes: str(1)
# memory usage: 476.0 bytes

# %%
df.describe()
# Out:
#                   Industry
# count                   43
# unique                  43
# top     Accounting/Finance
# freq                     1

# %%
df.tail()
# Out:
#                     Industry
# 38             Skilled Labor
# 39                Technology
# 40        Telecommunications
# 41  Transportation/Logistics
# 42                     Other

# %%
import numpy as np

data = {
    "Name": ["Ali", "Sara", "Omar", "Maha", "Ali", "Khalid", "Noor"],
    "Age": [25, 30, np.nan, 28, 25, 40, 120],
    "Gender": ["Male", "Female", "male", "Female", "Male", np.nan, "Female"],
    "Salary": [500, 700, 650, np.nan, 500, 900, 10000],
    "Department": ["IT", "Finance", "it", "HR", "IT", "Finance", "HR"],
    "Purchased": ["Yes", "No", "Yes", "No", "Yes", "Yes", "No"]
}

df = pd.DataFrame(data)
df
# Out:
#      Name    Age  Gender   Salary Department Purchased
# 0     Ali   25.0    Male    500.0         IT       Yes
# 1    Sara   30.0  Female    700.0    Finance        No
# 2    Omar    NaN    male    650.0         it       Yes
# 3    Maha   28.0  Female      NaN         HR        No
# 4     Ali   25.0    Male    500.0         IT       Yes
# 5  Khalid   40.0     NaN    900.0    Finance       Yes
# 6    Noor  120.0  Female  10000.0         HR        No

# %%
df.isna().sum()
# Out:
# Name          0
# Age           1
# Gender        1
# Salary        1
# Department    0
# Purchased     0
# dtype: int64

# %%
df.isna().sum() * 100
# Out:
# Name            0
# Age           100
# Gender        100
# Salary        100
# Department      0
# Purchased       0
# dtype: int64

# %%
df_drop = df.dropna()

# %%
df_drop
# Out:
#    Name    Age  Gender   Salary Department Purchased
# 0   Ali   25.0    Male    500.0         IT       Yes
# 1  Sara   30.0  Female    700.0    Finance        No
# 4   Ali   25.0    Male    500.0         IT       Yes
# 6  Noor  120.0  Female  10000.0         HR        No

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df["Salary"] = df["Salary"].fillna(df["Salary"].mean())

# %%
df
# Out:
#      Name         Age  Gender        Salary Department Purchased
# 0     Ali   25.000000    Male    500.000000         IT       Yes
# 1    Sara   30.000000  Female    700.000000    Finance        No
# 2    Omar   44.666667    male    650.000000         it       Yes
# 3    Maha   28.000000  Female   2208.333333         HR        No
# 4     Ali   25.000000    Male    500.000000         IT       Yes
# 5  Khalid   40.000000     NaN    900.000000    Finance       Yes
# 6    Noor  120.000000  Female  10000.000000         HR        No

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Salary"] = df["Salary"].fillna(df["Salary"].median())

# %%
df
# Out:
#      Name         Age  Gender        Salary Department Purchased
# 0     Ali   25.000000    Male    500.000000         IT       Yes
# 1    Sara   30.000000  Female    700.000000    Finance        No
# 2    Omar   44.666667    male    650.000000         it       Yes
# 3    Maha   28.000000  Female   2208.333333         HR        No
# 4     Ali   25.000000    Male    500.000000         IT       Yes
# 5  Khalid   40.000000     NaN    900.000000    Finance       Yes
# 6    Noor  120.000000  Female  10000.000000         HR        No

# %%
df["Gender"] = df["Gender"].fillna(df["Gender"].mode()[0])
df
# Out:
#      Name         Age  Gender        Salary Department Purchased
# 0     Ali   25.000000    Male    500.000000         IT       Yes
# 1    Sara   30.000000  Female    700.000000    Finance        No
# 2    Omar   44.666667    male    650.000000         it       Yes
# 3    Maha   28.000000  Female   2208.333333         HR        No
# 4     Ali   25.000000    Male    500.000000         IT       Yes
# 5  Khalid   40.000000  Female    900.000000    Finance       Yes
# 6    Noor  120.000000  Female  10000.000000         HR        No

# %%
df[df.duplicated()]
# Out:
#   Name   Age Gender  Salary Department Purchased
# 4  Ali  25.0   Male   500.0         IT       Yes

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      Name         Age  Gender        Salary Department Purchased
# 0     Ali   25.000000    Male    500.000000         IT       Yes
# 1    Sara   30.000000  Female    700.000000    Finance        No
# 2    Omar   44.666667    male    650.000000         it       Yes
# 3    Maha   28.000000  Female   2208.333333         HR        No
# 5  Khalid   40.000000  Female    900.000000    Finance       Yes
# 6    Noor  120.000000  Female  10000.000000         HR        No

# %%
df["Gender"].unique()

df["Gender"] = df["Gender"].str.title()

# %%
df["Gender"].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
df
# Out:
#      Name         Age  Gender        Salary Department Purchased
# 0     Ali   25.000000    Male    500.000000         IT       Yes
# 1    Sara   30.000000  Female    700.000000    Finance        No
# 2    Omar   44.666667    Male    650.000000         it       Yes
# 3    Maha   28.000000  Female   2208.333333         HR        No
# 5  Khalid   40.000000  Female    900.000000    Finance       Yes
# 6    Noor  120.000000  Female  10000.000000         HR        No

# %%
df["Department"] = df["Department"].str.upper()

df["Department"].unique()
# Out:
# <StringArray>
# ['IT', 'FINANCE', 'HR']
# Length: 3, dtype: str

# %%
df["Salary"] = pd.to_numeric(df["Salary"])

# %%
df
# Out:
#      Name         Age  Gender        Salary Department Purchased
# 0     Ali   25.000000    Male    500.000000         IT       Yes
# 1    Sara   30.000000  Female    700.000000    FINANCE        No
# 2    Omar   44.666667    Male    650.000000         IT       Yes
# 3    Maha   28.000000  Female   2208.333333         HR        No
# 5  Khalid   40.000000  Female    900.000000    FINANCE       Yes
# 6    Noor  120.000000  Female  10000.000000         HR        No

# %%
import pandas as pd
import numpy as np

data = {
    "Well": ["W1", "W2", "W3", "W4", "W5", "W6", "W7", "W8"],
    "Area": ["South", "South", "North", "North", "East", "East", "South", "North"],
    "Category": ["A", "B", "A", "C", "B", "C", "A", "B"],
    "Oil_Rate": [1200, 950, 1100, 400, 700, 300, 1500, 850],
    "Water_Cut": [20, 35, 25, 70, 45, 80, 15, 40],
    "Deferment_Hours": [5, 12, 3, 30, 15, 40, 2, 9],
    "MTTR": [2.5, 6.0, 1.5, 15.0, 8.0, 20.0, 1.0, 5.5],
    "Status": ["Online", "Offline", "Online", "Offline", "Online", "Offline", "Online", "Online"]
}

df = pd.DataFrame(data)

df
# Out:
#   Well   Area Category  Oil_Rate  Water_Cut  Deferment_Hours  MTTR   Status
# 0   W1  South        A      1200         20                5   2.5   Online
# 1   W2  South        B       950         35               12   6.0  Offline
# 2   W3  North        A      1100         25                3   1.5   Online
# 3   W4  North        C       400         70               30  15.0  Offline
# 4   W5   East        B       700         45               15   8.0   Online
# 5   W6   East        C       300         80               40  20.0  Offline
# 6   W7  South        A      1500         15                2   1.0   Online
# 7   W8  North        B       850         40                9   5.5   Online

# %%
df.loc[0:3 , ["Well" , "Area" , "Oil_Rate"]]
# Out:
#   Well   Area  Oil_Rate
# 0   W1  South      1200
# 1   W2  South       950
# 2   W3  North      1100
# 3   W4  North       400

# %%
df.iloc[0:3 , 0:4]
# Out:
#   Well   Area Category  Oil_Rate
# 0   W1  South        A      1200
# 1   W2  South        B       950
# 2   W3  North        A      1100

# %%
df.at[1 , "Well"]
# Out:
# 'W2'

# %%
df[df["Category"].isin(["South" , "North"])]
# Out:
# Empty DataFrame
# Columns: [Well, Area, Category, Oil_Rate, Water_Cut, Deferment_Hours, MTTR, Status]
# Index: []

# %%
df[df["Oil_Rate"].between(700 , 1200)]  #700 and 1200 included
# Out:
#   Well   Area Category  Oil_Rate  Water_Cut  Deferment_Hours  MTTR   Status
# 0   W1  South        A      1200         20                5   2.5   Online
# 1   W2  South        B       950         35               12   6.0  Offline
# 2   W3  North        A      1100         25                3   1.5   Online
# 4   W5   East        B       700         45               15   8.0   Online
# 7   W8  North        B       850         40                9   5.5   Online
